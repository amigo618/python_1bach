# %% [markdown]
# # Funciones en Python
#
# ---
#
# Hasta ahora, hemos escrito código desde arriba hacia abajo, pero esto no es siempre eficiente. En muchos casos es mucho más interesante compartimentalizar las operaciones en "máquinas" que podamos reutilizar. Estas máquinas se llaman **Funciones**.

# %% [markdown]
# ## Concepto de "Caja Negra" y Ámbito
#
# Una función es un caja aislada: lo que pasa dentro, se queda dentro. La funciones usan **`variables locales`**, declaradas en su interior, que sólo existen allí. Al terminar la función, éstas desaparecen.
#
# Tu programa principal no necesita saber *cómo* la función calcula el resultado, solo qué datos enviarle y qué esperar de vuelta.

# %%
# Variable GLOBAL: Visible desde cualquier parte del código
base_datos = "Servidor_Alfa"

# Definimos la función
def reportar_error():
    # Variable LOCAL: Solo existe aquí dentro del laboratorio
    identificador = "ERROR_505"
    
    # La función puede leer la global, pero usa sus locales para trabajar
    print(f"INFO: Se ha producido un error '{identificador}' en el sistema '{base_datos}'")

# Llamamos a la función: ejecutará su código interno
reportar_error()

# PRUEBA DE ÁMBITO:
# print(identificador)  # <--- ERROR: Esta línea haría explotar el programa.
# 'identificador' se destruyó al terminar la función.

# %% [markdown]
# ## Parámetros y Valores por Defecto
#
# Podemos configurar una función para que, además de realizar distintas operaciones, lo haga a partir de variables que nosotros le pasemos.
#
# También podemos hacer que estas variables tengan valores estándar, predefinidos, en caso de que el usuario no especifique nada. Esto hace que nuestro código sea más flexible y robusto.

# %%
def saludar_estacion(nombre, planeta="Marte"):
    print(f"Hola {nombre}, bienvenido a la base de {planeta}")

saludar_estacion("Nacho")            # Usará "Marte" por defecto
saludar_estacion("Elena", "Saturno") # Usará "Saturno"

# %% [markdown]
# ## Recuperando variables de una función: `return`
#
# No solamente podemos pasar información y variables a las funciones, también podemos recuperar información de la propia función cuando esta termine.
#
# **`return`** envía el dato de vuelta al programa principal. Es el "producto" que sale de la fábrica y que podemos guardar en una variable.

# %%
def calcular_presion_total(fuerza, superficie):
    # Calculamos la presión (Fuerza / Superficie)
    presion = fuerza / superficie
    
    return presion  # <--- Sacamos el dato de la función

# 1. Llamamos a la función y "atrapamos" el resultado en una variable
resultado_final = calcular_presion_total(500, 5)
print(resultado_final)

# %% [markdown]
# ---
# ## Debugging
# **Misión:** Este código intenta calcular el IVA de un producto, pero el programa falla.

# %%
def calcular_iva(precio):
    resultado_iva = precio * 0.21

mi_iva = calcular_iva(100)
print(f"El IVA a pagar es: {mi_iva}")

# %% [markdown]
# ---
# ## Retos
#
# ### 🟢 El Validador de Seguridad
# Crea una función llamada `es_seguro(valor)`.
# * **Lógica:** Si el número está entre 20 y 80 (inclusive), devuelve `True`. Si no, devuelve `False`.

# %%
### DESARROLLA AQUÍ TU PROGRAMA ###

# %% [markdown]
# ### 🟡 Conversor con Valor por Defecto
# Crea la función `convertir_presion(valor, factor=14.5)`.
# * **Misión:** Debe devolver el resultado de multiplicar el `valor` por el `factor`.
# * **Prueba:** Úsala primero con un solo dato (ej: 2) y luego con dos datos (ej: 2, 10.0) para ver cómo cambia el resultado.

# %%
### DESARROLLA AQUÍ TU PROGRAMA ###

# %% [markdown]
# ### 🟠 El Analizador de Lotes
# Crea una función llamada `analizar_sensor(lista_lecturas)`.
# * **Misión:** Debe recibir una lista de números y devolver un **diccionario** con dos claves: `"promedio"` y `"pico_maximo"`.

# %%
### DESARROLLA AQUÍ TU PROGRAMA ###

# %% [markdown]
# ### 🔴 Filtro de Alerta (Lógica combinada)
# Crea una función llamada `supera_limite(lista, limite)`.
# * **Misión:** Debe recorrer la lista y devolver `True` si **al menos uno** de los números es mayor que el `limite`. Si todos son menores, devuelve `False`.
# * **Entrada de prueba:** `[10, 50, 120, 30]`, limite `100` -> (Debe devolver `True`).

# %%
### DESARROLLA AQUÍ TU PROGRAMA ###
