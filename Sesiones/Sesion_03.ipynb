# %% [markdown]
# # Sesión 3: Estructuras de Datos: Listas y Diccionarios
# ---

# %% [markdown]
# Tras aprender como trabajar con variables numéricas, y dar el salto a los strings (cadenas de caracteres), en esta sesión iremos algo más lejos. Ahora pasaremos a trabajar con **colecciones** de datos.
#
# ## Listas (el orden importa)
# Las listas `[]` son como un conjunto de multiples variables. Sirven para guardar elementos en un orden determinado, y pueden estar compuestas tanto de variables numéricas como de strings.
#
# Como en los strings, los elementos de una lista pueden ser accedidos mediante `índices`. No obstante, las listas no son strings, y tienen métodos propios con mucho potencial.

# %%
fibonacci = [0, 1, 1, 2, 3, 5, 8, 13]
print(f"Los dos últimos números de la serie son {fibonacci[-2]} y {fibonacci[-1]}") # Las mismas normas para acceder elementos de un string también valen en listas
fibonacci.append(fibonacci[-2]+fibonacci[-1]) # Los métodos como append alteran las listas directamente, sin necesitarse declarar una nueva lista o variable
print(fibonacci)

# %% [markdown]
# Las listas pueden ser utilizadas para almacenar conjuntos o secuencias de datos, como en el caso anterior, pero también para muchas otras cosas.
#
# El orden, por ejmplo, tiene una gran importancia en el manejo de listas. Esto permite utilizarlas como "colas" de elementos, gestionando qué entra y qué sale, y en qué orden.

# %%
pedidos = ["Margarita", "Barbacoa", "Vegetal"]

pedidos.append("Hawaiana")         # Llega un nuevo pedido, y lo ponemos al final
primero = pedidos.pop(0)           # Sacamos el primer pedido para cocinarlo
                                   # De nuevo, los métodos de las listas alteran directamente la lista

print(f"Cocinando ahora: {primero}")
print(f"Pedidos pendientes (en orden): {pedidos}")

# %%
pedidos.insert(0,"Muerte Cárnica")   # Llega un pedido urgente, y se pone al principio para que se cocine antes que el resto
print(f"Pedidos pendientes tras pedido urgente (en orden): {pedidos}")

print(f"Siguiente en la cola: {pedidos[0]}")
print(f"Último en la cola: {pedidos[-1]}")

# %% [markdown]
# ## Diccionarios (el significado importa)
# Los diccionarios `{}` no funcionan mediante índices como las listas o los strings, sino por **Clave: Valor**. Como en los diccionarios lingüísticos, funcionan con "palabras" o "claves", que tienen asociados un "significado" o "valor".
#
# Por tanto, aquí no nos importa el orden, sino acceder al campo en particular.

# %%
notas = {
    "lengua": "no presentado",
    "mates": 6,
    "fisica": 7,
    "tecno": 8
}

print(f"El alumno ha sacado {notas['tecno']} en tecno, {notas['fisica']} en fisica, {notas['mates']} en mates y {notas['lengua']} en lengua")

# %%
notas["lengua"] = 5 # En un diccionario, es posible modificar el valor de una clave determinada de forma sencilla 
print(f"Tras la recuperación, el alumno ha sacado {notas['tecno']} en tecno, {notas['fisica']} en fisica, {notas['mates']} en mates y {notas['lengua']} en lengua")

# %% [markdown]
# ---
# # Debugging
#
# Un viajero espacial está reprogramando el ordenador de abordo. Debe arreglar el navegador, o de lo contratio la nave no sabrá como volver a casa.

# %%
### CÓDIGO CON ERRORES ###

# 1. Lista de planetas a explorar
planetas = ["Mercurio", "Venus"]
planetas = planetas.append("Tierra") # Intentamos añadir la Tierra pero algo sale mal en la asignación
print(f"El objetivo final de la misión: {planetas[3]}") # Comprobamos que el destino final es verdaderamente la Tierra

# 2. Diccionario con datos técnicos de la Tierra
datos_tierra = {"distancia_km": 105490, "radio_km": 6371, "habitado": True}
print(f"El planeta se encuentra a: {datos_tierra['distancia']} km") # El viajero intenta acceder a una clave, pero no funciona
velocidad_nave = 10000
print("Para llegar a la Tierra faltan: " + datos_tierra["distancia_km"] / velocidad_nave + " horas") # Quiere saber cuanto tardará, pero algo está mal

# %% [markdown]
# ---
# # Retos
#
# ### 🟢 Trayectoria de un Planeta
# Crea una lista llamada `distancias` que contenga: `[0, 15.5, 25.0, 30.2]`. Son valores en millones de km.
# 1. Pide al usuario la siguiente medición de distancia y añádela al final.
# 2. El primer valor (0) es el "la medición de calibración", elimínalo de la lista usando `.pop(0)`.
# 3. Imprime cuántas mediciones quedan y la distancia máxima alcanzada.

# %%
### DESARROLLA AQUÍ TO PROGRAMA ###

# %% [markdown]
# ### 🟡 Laboratorio de Isótopos
# Crea un diccionario para el **Carbono-12** con claves: `protones`, `neutrones` y `electrones` (todos valen 6).
# 1. El Carbono-14 tiene 2 neutrones más. Modifica el diccionario para que los neutrones sean 8.
# 2. Añade la clave `estable` con el valor `False`.
# 3. Imprime solo los valores del diccionario usando el método `.values()`.

# %%
### DESARROLLA AQUÍ TO PROGRAMA ###

# %% [markdown]
# ### 🟠 Registro de Desintegración
# Imagina que mides la actividad de una muestra radiactiva cada hora.
# Crea una lista llamada `muestras` que contenga tres diccionarios, uno por cada hora:
# * **Hora 0**: `{"tiempo": 0, "actividad": 100}`
# * **Hora 1**: `{"tiempo": 1, "actividad": 50}`
# * **Hora 2**: `{"tiempo": 2, "actividad": 25}`
#
# Imprime el valor de la "actividad" de la **segunda** medición (Hora 1) accediendo exclusivamente a través de la lista (ej: `muestras[indice]["actividad"]`).

# %%
### DESARROLLA AQUÍ TO PROGRAMA ###

# %% [markdown]
# ### 🔴 El Buscador Químico
# Crea un diccionario donde las claves sean símbolos químicos (`H`, `He`, `Li`, `Be`, `B`) y los valores sean sus nombres completos.
# Pide al usuario un símbolo mediante `input()`.
#
# * Si el símbolo existe en el diccionario, imprime el nombre completo.
# * Si no existe, imprime: `"Error: Elemento no registrado en la base de datos"`.

# %%
### DESARROLLA AQUÍ TO PROGRAMA ###
