# %% [markdown]
# # 🧬 Sesión 02: Ingeniería de Strings y Bioinformática
#
# Hoy vamos a tratar el texto no como simples palabras, sino como **datos estructurados**. En Python, los strings son secuencias inmutables. Esto significa que una vez creados, no se pueden modificar, pero sí podemos generar versiones nuevas y mejoradas.
#
# ---
# ## 1. Teoría Práctica I: Indexación y Slicing (Rebanado)
# Cada carácter de un string ocupa una posición fija llamada **índice**.
#
#
#
# ### Ejemplo 1: Acceso directo y rangos
# Ejecuta esta celda para ver cómo extraer partes específicas de una secuencia de ADN.

# %%
secuencia = "ATGCGTAC"

print(f"Primer nucleótido: {secuencia[0]}")
print(f"Último nucleótido: {secuencia[-1]}")
print(f"Primer triplete (codón): {secuencia[0:3]}")  # Del índice 0 al 2 (el 3 no se incluye)
print(f"Desde el índice 4 hasta el final: {secuencia[4:]}")
print(f"Invertir toda la cadena: {secuencia[::-1]}")

# %% [markdown]
# ## 2. Teoría Práctica II: Transformación de Datos
# Los datos científicos suelen venir con errores de formato (minúsculas, espacios, etc.). Python tiene métodos integrados para normalizar el texto.
#
# ### Ejemplo 2: Limpieza y Normalización
# Observa cómo tratamos una entrada de usuario "sucia".

# %%
entrada_laboratorio = "   aTgC_gtAc   "

limpia = entrada_laboratorio.strip()  # Quita espacios
limpia = limpia.replace("_", "")      # Quita caracteres extraños
mayuscula = limpia.upper()            # Todo a mayúsculas

print(f"Original: '{entrada_laboratorio}'")
print(f"Procesada: '{mayuscula}'")

# %% [markdown]
# ## 3. Teoría Práctica III: Búsqueda y Análisis
# A veces necesitamos saber si un patrón existe dentro de una cadena de miles de caracteres.
#
# ### Ejemplo 3: Localización de patrones
# Vamos a buscar el codón de inicio 'ATG'.

# %%
genoma = "CGTTAGCTAATGCGTAA"

posicion = genoma.find("ATG")
conteo_a = genoma.count("A")

print(f"El codón ATG empieza en el índice: {posicion}")
print(f"Número total de Adeninas (A): {conteo_a}")
print(f"¿Existe la secuencia 'ZZZ'?: {'ZZZ' in genoma}")

# %% [markdown]
# ## 4. Bloque de Debugging 🛠️
# Un investigador ha intentado programar un corrector automático de ADN. El código no da error de ejecución, pero **no hace nada de lo que se le pide**.
#
# **Misión:** Encuentra por qué la variable `secuencia` no cambia.

# %%
secuencia = "  atgcgtac  "

secuencia.strip()
secuencia.upper()
secuencia.replace("a", "T")

print(f"Resultado esperado: TGCGTAC")
print(f"Resultado real: '{secuencia}'")

# %% [markdown]
# ## 5. Retos de Programación 🚀
#
# ### 🟢 Reto 1: El Validador de Secuencias
# Pide una secuencia al usuario. El programa debe imprimirla limpia (sin espacios), en mayúsculas y decir cuántos nucleótidos tiene en total.

# %%
# Tu código aquí

# %% [markdown]
# ### 🟡 Reto 2: El Ratio de Estabilidad (GC)
# Calcula el % de GC sobre el total.
# Fórmula: `(G + C) / Longitud * 100`

# %%
# Tu código aquí

# %% [markdown]
# ### 🟠 Reto 3: Extractor de Genes
# Pide una secuencia. Busca 'ATG'. Si lo encuentra, imprime la secuencia que va desde ese 'ATG' hasta el final. Si no lo encuentra, indica 'No es un gen válido'.

# %%
# Tu código aquí

# %% [markdown]
# ### 🔴 Reto 4 (Ninja): Complemento Inverso
# En bioinformática es común invertir la cadena y cambiar las bases: A->T, T->A, G->C, C->G.
# **Misión:** Pide una secuencia y devuelve su complemento inverso.
# *Pista: Para no sobreescribir las letras al usar replace, prueba a pasar los cambios a minúsculas temporalmente.*

# %%
# Tu código aquí
