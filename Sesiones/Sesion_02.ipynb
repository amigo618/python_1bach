# %% [markdown]
# # 🧬 Sesión 02: Ingeniería de Strings y Bioinformática
#
# ## 1. Teoría Activa: La anatomía de las cadenas
# En programación, un **String** es una secuencia de caracteres. En Python, las cadenas son **inmutables** (no se pueden cambiar una vez creadas, solo transformarlas en una nueva).
#
# ### A. Indexación y Slicing (Rebanado)
# Cada letra tiene una posición o **índice**:
# * El primer índice es **0**.
# * El último índice es **-1**.
#
# Sintaxis del Slicing: `cadena[inicio : fin : paso]`
#
#
#
# ### B. Métodos de limpieza
# * `.upper()` / `.lower()`: Cambiar a mayúsculas o minúsculas.
# * `.strip()`: Eliminar espacios accidentales.
# * `.replace("A", "B")`: Sustituir caracteres.
# * `.find("patrón")`: Busca la posición de un texto.

# %% [markdown]
# ## 2. Bloque de Debugging 🛠️
# Un científico ha recibido una secuencia de ADN, pero su programa falla al intentar procesarla.
# **Misión:** Encuentra los errores lógicos en este código y haz que funcione correctamente.

# %%
# --- CÓDIGO CON ERRORES ---
secuencia_raw = "  atgCgtacGttAa  "

# 1. Queremos quitar los espacios en blanco
secuencia_raw.strip() 

# 2. Queremos que todo sea mayúsculas
secuencia_raw.upper()

# 3. Intentamos cambiar la primera letra a 'T' manualmente
secuencia_raw[0] = "T" 

print(f"Secuencia final: {secuencia_raw}")

# %% [markdown]
# ## 3. Retos de Programación 🚀
#
# ### 🟢 Reto 1 (Fácil): El Contador de Bases
# Pide una secuencia de ADN. El programa debe:
# 1. Limpiar espacios y pasar a mayúsculas.
# 2. Contar cuántas 'A' y cuántas 'T' hay e imprimirlas.

# %%
# Escribe aquí el Reto 1

# %% [markdown]
# ### 🟡 Reto 2 (Normal): Contenido GC
# Calcula el porcentaje de Guanina (G) y Citosina (C) sobre el total de la cadena.
# Fórmula: `%GC = (G + C) / Longitud_Total * 100`

# %%
# Escribe aquí el Reto 2

# %% [markdown]
# ### 🟠 Reto 3 (Difícil): El Buscador de Codones
# Busca el codón de inicio **'ATG'**. Si existe, muestra su posición y extrae los 10 caracteres siguientes. Si no, avisa al usuario.

# %%
# Escribe aquí el Reto 3

# %% [markdown]
# ### 🔴 Reto 4 (Ninja): La Cadena Complementaria
# 1. Invierte la secuencia.
# 2. Crea la complementaria: A <-> T y G <-> C.
# *Pista: Cuidado con usar .replace() directamente, ¡puedes sobreescribir lo que acabas de cambiar!*

# %%
# Escribe aquí el Reto 4
