# %% [markdown]
# # Sesión 02: Strings en Python
# ---

# %% [markdown]
# ## Indexación y Rebanado (Slicing)
#
# En programación los textos no se componen de frases o palabras, sino de caracteres. A estas cadenas de caracteres las llamamos **strings**.
#
# Python permite "sumar" y "multiplicar" strings, pero los resultados son muy distintos a los que vimos trabajando con datos numéricos...

# %%
print(f"He aquí la suma de dos cadenas: {'chachi'+'piruli'}") # La suma no es sino una concatenación de 2 strings
print(f"Y aquí la multiplicación de una: {5*'bla'}") # La multiplicación concatena n veces una misma secuencia

# %% [markdown]
# Estos strings son **datos estructurados**, una especie de "vectores" en los que cada carácter es una variable en sí misma: parte de la cadena pero accesible "independientemente".
#
# Cada caracter de un string ocupa una posición fija llamada **índice**. Para acceder a ese caracter se utilizan los corchetes: `string[índice]`

# %%
cadena = "¡vivan las cadenas! 🔗"

print(f"Primer caracter: {cadena[0]}") # El 0 es el primer índice
print(f"Último caracter: {cadena[-1]}") # El -1 es el último en cambio

# %% [markdown]
# No solo podemos acceder a caractéres en particular, también a conjuntos de ellos. Esto se hace incluyendo un par de indices dentro de los corchetes, separados por "**:**", así: `string[índice_inicio :índice_final]`

# %%
print(f"Primeros tres caracteres: {cadena[0:3]}")  # Del índice 0 al 2 (el 3 no se incluye)
print(f"Desde el índice 4 hasta el final: {cadena[4:]}") # Del índice 4 (5º elemento) hasta el final
print(f"Desde el índice 4 hasta el final: {cadena[:-4]}") # Desde el principio hasta el índice 4 (5º elemento) contando desde el final

# %% [markdown]
# La versión más avanzada de este proceso permite recorrer las cadenas o strings entre dos índices, con un "paso" concreto: `string[índice_inicio:índice_final:paso]`
#
# La aplicación más interesante es la inversión de cadenas, pues Python entiende que si el **paso es negativo** debe recorrer la cadena en **dirección contraria, empezando por el final**.

# %%
print(f"Solo los caracteres pares: {cadena[::2]}")
print(f"Solo los caracteres impares: {cadena[1::2]}")

print(50*"-")

print(f"Toda la cadena invertida: {cadena[::-1]}")
print(f"Solo pares empezando por el final: {cadena[::-2]}")

# %% [markdown]
# ## Limpieza y Normalización
# Trabajando con strings es habitual encontrar errores y problemas de formato (minúsculas, espacios, etc.). No obstante, Python tiene métodos integrados para limpiar y normalizar el texto.
#
# Esto permite gestionar cadenas erroneas o "sucias".

# %%
cadena_sucia = "   #VivAn LaS$ CadEnAS$!   "

cadena_limpia = cadena_sucia.strip()   # Quita espacios "excesivos", al principio o al final

cadena_limpia = cadena_limpia.replace("$", "")      # Quita caracteres extraños
cadena_limpia = cadena_limpia.replace("#", "¡")      # Sustituye caracteres erroneos

cadena_limpia = cadena_limpia.lower()   # Todo a minúsculas (para mayúsculas puede usarse "upper()")

print(f"Original: '{cadena_sucia}'")
print(f"Procesada: '{cadena_limpia}'")

# %% [markdown]
# ### Localización de patrones
# A veces necesitamos saber si un patrón existe dentro de una cadena de miles o millones de caracteres, y por supuesto hacerlo a mano no es una opción.
#
# Usando ciertas funciones podemos construir un "buscador avanzado" con Python.

# %%
carta_restaurante = """Pizza Margarita - INGREDIENTES: Tomate, Mozzarella, Albahaca, Queso - PRECIO: 10.00€
Pizza Carbonara - INGREDIENTES: Nata, Bacon, Cebolla, Queso, Champiñón - PRECIO: 11.00€
Pizza Barbacoa - INGREDIENTES: Pollo, Bacon, Salsa BBQ, Queso - PRECIO: 12.00€
Pizza Diabola - INGREDIENTES: Salami Picante, Guindilla, Tomate, Queso - PRECIO: 10.50€
Pizza Vegetal 100% - INGREDIENTES: Pimiento, Champiñón, Calabacín, Tomate - PRECIO: 10.00€
Pizza Hawaiana - INGREDIENTES: Jamón York, Piña, Tomate, Queso - PRECIO: 11.50€
Pizza Marinera - INGREDIENTES: Atún, Gambas, Mejillones, Ajo, Queso - PRECIO: 13.50€
Pizza Cuatro Quesos - INGREDIENTES: Parmesano, Gorgonzola, Roquefort, Mozzarella - PRECIO: 12.00€
Pizza Calzone - INGREDIENTES: Jamón, Huevo, Champiñón, Queso - PRECIO: 12.50€
Pizza Intoxicación Cárnica - INGREDIENTES: Bacon, Ternera, Pollo, Salami Picante, Jamón, y el resto de carnes en carta - PRECIO: 15.00€
"""

longitud = len(carta_restaurante)
líneas = len(carta_restaurante.splitlines())
posicion = carta_restaurante.find("Queso")
count_queso = carta_restaurante.count("Queso")

print(f"La carta tiene {longitud} caracteres y {líneas} platos")
print(f"La primera mención a 'Queso' está en: {posicion}")
print(f"Hay {count_queso} pizzas con queso, solo {líneas-count_queso} son aptas para intolerantes a la lactosa")
print(f"¿Hay carne de 'Avestruz' en la carta? {'Avestruz' in carta_restaurante}")

# %% [markdown]
# ---
# # Debugging 🛠️
# Los strings no son solo importantes en lenguajes, también son muy utiles para cualquier información "estructurada". Por ejemplo, el ADN.
#
# Un investigador ha intentado programar un corrector automático de ADN, que limpie y prepare una cadena original "bruta", no normalizada, y después modifique la primera letra. El código no da error de ejecución, pero **no hace lo que quiere**. Encuentra por qué la variable `secuencia` no cambia y completa el programa para que el resultado real coincida con el esperado.

# %%
### CÓDIGO CON ERRORES ###

secuencia = "  atgcgtac  "

secuencia.strip()
secuencia.upper()
secuencia.replace("a", "T")

print(f"Resultado esperado: TGCGTAC")
print(f"El resultado real : {secuencia}")

# %% [markdown]
# ---
# ## Retos
#
# ### 🟢 El Validador de Secuencias
# Pide una secuencia al usuario. El programa debe imprimirla limpia (sin espacios), en mayúsculas e indicar### DESARROLLA AQUÍ TO PROGRAMA ### cuántos nucleótidos tiene en total.

# %%
### DESARROLLA AQUÍ TU PROGRAMA ###

# %% [markdown]
# ### 🟡 El Ratio de Estabilidad (GC)
# El "enlace" entre G y C es mucho más fuerte que el formado por A y T. Por tanto, la estabilidad de una cadena de ADN depende en gran medida del porcentaje que tenga de guanina y citosina.
#
# Calcula el % de GC sobre el total.
# Fórmula: `(G + C) / Longitud * 100`

# %%
### DESARROLLA AQUÍ TU PROGRAMA ###

# %% [markdown]
# ### 🟠 Extractor de Genes
# El ADN está formado por nucleótidos, cuya secuencia determina las proteinas que el cuerpo produce para su funcionamiento. A esta secuencia codificadora la llamamos **gen**.
#
# EN este contexto, un triplete es un conjunto de tres nucleótidos, que codifica un aminoácido. Una proteina no es más que el conjuto de los aminoácidos, uno tras otro, codificados por los tripletes de un gen en particular.
#
# No obstante, es necesario diferenciar que es parte de un gen y que no, así que la naturaleza tiene un recurso inteligente: "señales de control". Al triplete **ATG** se la denomina codón de inicio, e indica a cual es el inicio de un gen.
#
# Pide una secuencia al usuario, busca en ella el triplete 'ATG', e imprime el gen completo (considerando que el gen empieza en el triplete y acaba al final de la cadena dada).

# %%
### DESARROLLA AQUÍ TU PROGRAMA ###

# %% [markdown]
# ### 🔴 Complemento Inverso
#
# En bioinformática es común invertir una cadena de ADN y cambiar las bases: A->T, T->A, G->C, C->G.
#
# Genera un código que pida una secuencia y devuelva su complemento inverso.

# %%
### DESARROLLA AQUÍ TU PROGRAMA ###
