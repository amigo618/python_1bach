# %% [markdown]
# # Práctica 1: La Lógica del Programador
#
# En este cuaderno no importa sólo el código; tu capacidad para **explicar la lógica** es lo que demuestra que dominas Python.

# %% [markdown]
# ---
# ## Bloque 1: Desarrollo
# *Escribe el código y razona tu respuesta en la celda de texto.*

# %% [markdown]
# ### 1. La Taquilla del Cine
# Crea un programa que pida la **edad** del usuario y el **día de la semana**.
#
# Si el usuario tiene menos de 18 años **O** si es "miércoles" (día del espectador), la entrada cuesta **5€**. En cualquier otro caso, cuesta 9€.
#
# * **Misión:** Imprime el precio final de la entrada según los datos de entrada.
# * **Consejo:** El método "input" guarda la información como texto, a veces debe transformarse en int o float.

# %%
# DESARROLLA TU PROGRAMA

# %% [markdown]
# **Explica tu programa:**

# %% [markdown]
# ### 2. El Sensor Inteligente (Listas + Cálculo Filtrado)
# Dada la lista `lecturas = [10, -5, 20, -2, 30, -8, 10]`.
# * **Misión:** Crea un programa que sume **solo los números positivos** y, al final, calcule la media de esos números positivos.
# * **Consejo:** Todo se simplifica si se crea una nueva lista, y después se calcula la media con sum() y len().

# %%
lecturas = [10, -5, 20, -2, 30, -8, 10]

# DESARROLLA TU PROGRAMA

# %% [markdown]
# **Explica tu programa:**

# %% [markdown]
# ### 3. Validador de Seguridad
# Pide al usuario que cree una **contraseña**.
#
# Para ser segura debe tener más de 8 caracteres **Y** contener un asterisco (`*`).
#
# * **Misión:** Imprime "Contraseña segura" o "Contraseña débil" según corresponda.
# * **Consejo:** El operador **in** permite saber si un texto contienen unos caracteres

# %%
# DESARROLLA TU PROGRAMA

# %% [markdown]
# **Explica tu programa:**

# %% [markdown]
# ### 4. Tabla de Multiplicar Selectiva
# Pide un número entero al usuario.
# * **Misión:** Crea la tabla de multiplicar del número introducido, desde el 1 hasta el 10, e imprimela por pantalla.
# * **Consejo:** Parte de un bucle for, pero utiliza la función **range()** adecuadamente.

# %%
# DESARROLLA TU PROGRAMA

# %% [markdown]
# **Explica tu programa:**

# %% [markdown]
# ### 5. Buscador con Aviso
# Tienes la lista `frutas = ["manzana", "pera", "platano", "uva"]`. Pide al usuario una fruta.
# * **Misión:** Recorre la lista. Si la fruta está, imprime "¡La tengo!". Si recorres toda la lista y no está, imprime "No la encuentro".
# * **Consejo:** Crea una variable y asignale el valor "False". Sólo si la fruta está en la lista cambialo a "True". Crea la lógica a partir de esta variable.

# %%
frutas = ["manzana", "pera", "platano", "uva"]

# DESARROLLA TU PROGRAMA

# %% [markdown]
# **Explica tu programa:**

# %% [markdown]
# ---
# ## Bloque 2: Análisis
# *Analiza los códigos proporcionados y explica el resultado final.*

# %% [markdown]
# ### 6. El Bucle con Saltos

# %%
for i in range(2, 11, 2):
    print(f"Número: {i}")

# %% [markdown]
# **Pregunta:** ¿Qué números aparecen en pantalla? ¿Por qué? Explica la progresión de la variable `i` en el bucle.

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# ### 7. El Mensaje Cifrado

# %%
frase = "Hola Mundo"
resultado = ""
for letra in frase:
    if letra == "o":
        resultado = resultado + "*"
    else:
        resultado = resultado + letra
print(resultado)

# %% [markdown]
# **Pregunta:** ¿Qué ocurre con la frase original? ¿Por qué? Explica el proceso de cómo se construye la variable `resultado`.

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# ### 8. El Sensor de Emergencia

# %%
voltajes = [220, 225, 300, 218]
for v in voltajes:
    if v > 250:
        print("¡PELIGRO!")
        break
    print(f"Voltaje estable: {v}")

# %% [markdown]
# **Pregunta:** ¿Qué voltajes llegan a imprimirse por pantalla? ¿Por qué se para el proceso? Explica paso a paso como avanza el programa.

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# ### 9. El Acumulador con Resta

# %%
bolsa = [10, 20, 5]
total = 100
for cantidad in bolsa:
    total = total - cantidad
print(total)

# %% [markdown]
# **Pregunta:** ¿Qué valor tiene `total` al final? ¿Por qué? Explica cómo va cambiando la variable en cada paso del bucle.

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# ### 10. La Lista al Revés

# %%
letras = ["A", "B", "C"]
final = ""
for x in letras:
    final = x + final
print(final)

# %% [markdown]
# **Pregunta:** ¿Qué palabra se forma al final? ¿Por qué? Describe cómo se va generando paso a paso.

# %% [markdown]
# **Respuesta:**
