# %% [markdown]
# # 🚀 Repaso de Lógica: Nivel Intermedio
#
# Este cuaderno te pondrá a prueba. No solo cuenta el código; tu capacidad para **explicar la lógica** es lo que demuestra que dominas Python.
#
# ---
# ## 🛠️ Bloque 1: Desarrollo (Creación y Explicación)
# *Escribe el código y razona tu respuesta en la celda de texto.*

# %% [markdown]
# ### 1. La Taquilla del Cine (Condiciones Compuestas)
# Pide la **edad** del usuario y el **día de la semana**.
# * **Regla:** La entrada cuesta 5€ si el usuario tiene menos de 18 años **O** si es "miércoles" (día del espectador). En cualquier otro caso, cuesta 9€.
# * **Misión:** Imprime el precio final.

# %%
# Tu código aquí

# %% [markdown]
# **✍️ Tu explicación:**

# %% [markdown]
# ### 2. El Sensor Inteligente (Listas + Cálculo Filtrado)
# Dada la lista `lecturas = [10, -5, 20, -2, 30, -8, 10]`.
# * **Misión:** Crea un programa que sume **solo los números positivos** y, al final, calcule la media de esos números positivos.

# %%
lecturas = [10, -5, 20, -2, 30, -8, 10]

# Tu código aquí

# %% [markdown]
# **✍️ Tu explicación:**

# %% [markdown]
# ### 3. Validador de Seguridad (Strings + Lógica)
# Pide al usuario que cree una **contraseña**.
# * **Regla:** Para ser segura debe tener más de 8 caracteres **Y** contener un asterisco (`*`).
# * **Misión:** Imprime "Contraseña segura" o "Contraseña débil" según corresponda.

# %%
# Tu código aquí

# %% [markdown]
# **✍️ Tu explicación:**

# %% [markdown]
# ### 4. Tabla de Multiplicar Selectiva (Bucles + Filtro)
# Pide un número al usuario (ej: el 5).
# * **Misión:** Muestra su tabla de multiplicar del 1 al 10, pero **solo imprime los resultados que sean pares**.

# %%
# Tu código aquí

# %% [markdown]
# **✍️ Tu explicación:**

# %% [markdown]
# ### 5. Buscador con Aviso (Banderas / Booleano)
# Tienes la lista `frutas = ["manzana", "pera", "platano", "uva"]`. Pide al usuario una fruta.
# * **Misión:** Recorre la lista. Si la fruta está, imprime "¡La tengo!". Si recorres toda la lista y no está, imprime "No la encuentro".

# %%
frutas = ["manzana", "pera", "platano", "uva"]

# Tu código aquí

# %% [markdown]
# **✍️ Tu explicación:**

# %% [markdown]
# ---
# ## 🔍 Bloque 2: Comprensión (Análisis de Código)
# *Analiza los códigos y explica el resultado final sin ejecutarlos.*

# %% [markdown]
# ### 6. El Bucle que Esquiva
# ```python
# for i in range(1, 6):
#     if i == 3:
#         continue
#     print(i)
# ```
# **Pregunta:** ¿Qué números aparecerán en pantalla? ¿Qué ha hecho exactamente la instrucción `continue`?

# %% [markdown]
# **✍️ Tu respuesta:**

# %% [markdown]
# ### 7. El Mensaje Oculto
# ```python
# frase = "Hola Mundo"
# resultado = ""
# for letra in frase:
#     if letra == "o":
#         resultado = resultado + "*"
#     else:
#         resultado = resultado + letra
# print(resultado)
# ```
# **Pregunta:** ¿Cómo se verá la frase final? Explica el proceso de cómo se construye la variable `resultado`.

# %% [markdown]
# **✍️ Tu respuesta:**

# %% [markdown]
# ### 8. La Cuenta Atrás Incompleta
# ```python
# num = 10
# while num > 5:
#     print(num)
#     num = num - 2
# ```
# **Pregunta:** ¿Qué números se imprimirán? ¿Por qué el bucle se detiene?

# %% [markdown]
# **✍️ Tu respuesta:**

# %% [markdown]
# ### 9. El Acumulador con Resta
# ```python
# bolsa = [10, 20, 5]
# total = 100
# for cantidad in bolsa:
#     total = total - cantidad
# print(total)
# ```
# **Pregunta:** ¿Qué valor tendrá `total` al final? Explica cómo va cambiando la variable en cada paso del bucle.

# %% [markdown]
# **✍️ Tu respuesta:**

# %% [markdown]
# ### 10. La Lista al Revés
# ```python
# letras = ["A", "B", "C"]
# final = ""
# for x in letras:
#     final = x + final
# print(final)
# ```
# **Pregunta:** ¿Qué palabra se formará al final? Fíjate bien en el orden de `x + final` y explícalo.

# %% [markdown]
# **✍️ Tu respuesta:**
