# %% [markdown]
# # 🚀 Sesión 10: El Arquitecto de Algoritmos (Vibe Coding)
#
# **Misión:** Diseñar, simular y analizar un Bot de Inversión inteligente utilizando Python y la asistencia de una IA.
#
# Hoy dejas de ser un aprendiz para convertirte en un **Arquitecto de Sistemas**. Tu trabajo es definir la estrategia, supervisar los resultados y usar a la IA como tu copiloto para resolver la sintaxis técnica.
#
# ---

# %% [markdown]
# ## 🛠️ Guía de Supervivencia: Cómo trabajar con la IA
#
# Para que tu bot funcione a la primera, sigue estas reglas de comunicación con tu asistente (Gemini/ChatGPT):
#
# 1. **Divide y Vencerás:** No pidas todo el programa de golpe. Primero pide los datos, comprueba que existen, y luego pide la lógica.
# 2. **Contexto Preciso:** Si tu lista de datos se llama `precios`, recuérdaselo a la IA: *"Usa la lista llamada precios que ya tengo cargada"*.
# 3. **Copia el Error:** Si sale una franja roja, no intentes arreglarlo tú. Copia el error entero, pégalo en la IA y dile: *"Tengo este error, arréglalo manteniendo mi estrategia"*.
# 4. **Itera sin Miedo:** Si el bot no gana dinero, cambia las reglas. Dile a la IA: *"Esta estrategia es muy conservadora, haz que compre cuando el precio baje un 2% en lugar de un 5%"*.
#
# ---

# %% [markdown]
# ### 📡 Bloque 1: Conexión y Datos (API)
#
# **Objetivo:** Descargar los precios reales de **Bitcoin** del último año.
#
# **Instrucciones para el alumno:**
# * Pídele a la IA que use `yfinance` para descargar datos de 'BTC-USD'.
# * **Punto clave:** Pídele específicamente que extraiga la columna 'Close' usando `.iloc[:, 0]` y la convierta en una **lista de Python** llamada `precios`.

# %%
# 1. Instala la librería si es necesario (quita el # de la línea de abajo)
# !pip install yfinance

# 2. Pídele aquí a la IA el código para descargar los datos y crear la lista 'precios'

# %% [markdown]
# ---
# ### 🧠 Bloque 2: El Cerebro (Algoritmo de Inversión)
#
# **Objetivo:** Crear un simulador que recorra los días y decida cuándo comprar o vender.
#
# **Tu Reto:** Define tu estrategia. ¿Cuánto debe bajar el precio para que compres? ¿Cuánto quieres ganar antes de vender? La IA usará la lógica de la variación porcentual:
#
# $$\Delta P = \frac{P_{hoy} - P_{ayer}}{P_{ayer}}$$
#
# **Instrucciones para el alumno:**
# * Explícale a la IA tu plan en lenguaje natural.
# * Pídele que gestione variables para el **efectivo**, la **cripto en cartera** y el **valor total** de tu riqueza cada día.

# %%
# Pídele aquí a la IA que cree el bucle de inversión basado en tu estrategia.
# Asegúrate de que guarde los resultados en una lista llamada 'historial_patrimonio'.

# %% [markdown]
# ---
# ### 📊 Bloque 3: El Espejo (Visualización)
#
# **Objetivo:** Crear un gráfico profesional para ver si tu estrategia ha funcionado.
#
# **Instrucciones para el alumno:**
# * Pídele a la IA que use `matplotlib` para mostrar la evolución de tu dinero.
# * Pídele que el gráfico sea elegante (estilo 'fivethirtyeight') y que marque con una línea tus 1000 USD iniciales.

# %%
# Pídele aquí a la IA el código para visualizar la evolución de 'historial_patrimonio'.

# %% [markdown]
# ---
# ## 🚩 Reto Extra: Comisiones Reales
#
# En el mercado real, cada operación tiene un coste.
#
# **El Desafío:** Pídele a la IA que modifique tu código anterior para que cada compra y cada venta reste **5 USD** de comisión fija. ¿Tu estrategia sigue siendo ganadora tras pagar al exchange?
