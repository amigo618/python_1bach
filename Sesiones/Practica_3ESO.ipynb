# %% [markdown]
# # Sesión Práctica: Primeros Retos en Python
#
# Lee atentamente las instrucciones de cada reto. Escribe tu código en la celda gris que hay debajo de cada uno y ejecutalo probar si funciona.

# %% [markdown]
# ### Reto 1: La máquina del tiempo
# Escribe un programa que pregunte al usuario en qué año nació. Luego, el programa debe calcular cuántos años cumple (o ha cumplido) en el año actual (2026) y mostrar el resultado en pantalla.
#
# *Pista: Recuerda que lo que el usuario escribe se guarda como texto*

# %%
# Escribe aquí tu código para el Reto 1

# %% [markdown]
# ### Reto 2: El radar de velocidad
# Imagina que un coche va a cierta velocidad. Ya tienes la variable creada abajo (le damos un valor de, por ejemplo, 130 km/h).
#
# Usa un condicional (`if` / `else`) para que el programa imprima **"Multa"** si la velocidad es mayor a 120, o imprima **"Velocidad legal"** si es 120 o menor.

# %%
velocidad = 130

# Escribe aquí tu código para el Reto 2

# %% [markdown]
# ### Reto 3: El megáfono automático
# Tienes una lista con tus 3 comidas favoritas. En lugar de imprimir la lista entera de golpe, usa un bucle `for` para que el programa imprima cada comida en una línea separada, añadiendo el texto **"Me encanta comer "** delante de cada una.

# %%
comidas = ["pizza", "macarrones", "helado"]

# Escribe aquí tu código para el Reto 1

# %% [markdown]
# ### Reto 4: Romper la hucha
# Tienes una lista con las monedas que hay dentro de una hucha. También tienes una variable `total` que empieza en 0.
#
# Usa un bucle `for` para recorrer las monedas y sumarlas a la variable `total`. Al terminar el bucle, imprime en pantalla un mensaje diciendo cuánto dinero tienes ahorrado en total.

# %%
monedas = [2, 1, 2, 5]
total = 0

# Escribe aquí tu código para el Reto 1
