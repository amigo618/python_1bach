# %% [markdown]
# # 🏁 Entrenamiento de Examen: Control de Calidad "Cyber-Fábrica"
#
# **Objetivo:** Demostrar el dominio de bucles, condicionales y procesamiento de listas/strings antes del examen.
#
# ---
# ## 🛠️ Calentamiento: Debugging (5 min)
# El siguiente código intenta procesar una lectura, pero tiene **3 errores críticos**. Corrígelos para que funcione.

# %%
lectura = "OK_45"

if lectura.startswith("OK")
valor = lectura[3:]
if valor > 30:
    print("Peso excesivo")

# %% [markdown]
# ---
# ## 🚀 Los Retos de la Misión
#
# ### 🟢 Reto 1: Limpieza de Lote
# **Entrada obligatoria:** `cinta_transportadora = ["OK_25", "ERR_15", "OK_42", "ERR_05", "OK_100"]`
#
# Crea una lista vacía llamada `piezas_validas`. Recorre la cinta con un bucle `for` y, **solo si** la pieza empieza por `"OK_"`, extrae el número, conviértelo a entero y añádelo a la nueva lista.

# %%
cinta_transportadora = ["OK_25", "ERR_15", "OK_42", "ERR_05", "OK_100"]
piezas_validas = []

# Escribe tu código aquí

# %% [markdown]
# ### 🟡 Reto 2: El Filtro de Tolerancia
# Usa la lista `piezas_validas` resultante del reto anterior.
# * Si el valor es **mayor de 90**: Imprime `"⚠️ [VALOR] - Pieza demasiado pesada."`
# * Si el valor está **entre 20 y 90 (incluidos)**: Imprime `"✅ [VALOR] - Peso correcto."`
# * Si el valor es **menor de 20**: Imprime `"❌ [VALOR] - Peso insuficiente."`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 🟠 Reto 3: Auditoría Final
# 1. Calcula la **media de peso** de las `piezas_validas` (suma / total).
# 2. Si la media es **superior a 30 Y tienes más de 2 piezas** válidas: Imprime `"🚀 Lote APROBADO para envío"`.
# 3. De lo contrario: Imprime `"🛑 Lote RECHAZADO"`.

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## 🏆 Reto 4: Nivel Élite (Oculto)
# **Contexto:** El sistema ha recibido interferencias. Modifica tu lógica del Reto 1 para usar esta nueva lista:
# `cinta_elite = ["OK_25", "basura", "ERR_15", "OK_42", "STOP", "OK_100", "88"]`
#
# **Reglas:**
# 1. Si el código es exactamente `"STOP"`, el programa debe imprimir `"🛑 PARADA DE EMERGENCIA"` y **detener el bucle** inmediatamente.
# 2. El programa **no debe dar error** al encontrar palabras como "basura" (comprueba que empiece por "OK_" antes de convertir a número).
# 3. Cuenta cuántos elementos han sido ignorados (los que no son OK ni STOP).

# %%
cinta_elite = ["OK_25", "basura", "ERR_15", "OK_42", "STOP", "OK_100", "88"]

# Escribe tu código aquí
