# %% [markdown]
# # 🚀 Sesión 1: Python como Laboratorio de Alta Precisión
# **Objetivo:** Dominar la aritmética computacional y entender cómo Python procesa los datos numéricos.
#
# ---
# ## 1. Descubrimiento: La "Lógica" de la Máquina
# En Python, los números no son solo números. Tienen **naturaleza**.
# * **int**: Enteros (puros, sin pérdida).
# * **float**: Decimales (aproximaciones binarias).
#
# ### Operadores Especiales:
# | Operador | Nombre | Función |
# | :--- | :--- | :--- |
# | `//` | División Entera | Quita los decimales del resultado. |
# | `%` | Módulo | Devuelve el resto de una división. |
# | `**` | Potencia | Eleva un número a otro. |

# %%
# EJECUTAR ESTO PARA EXPERIMENTAR
distancia_luz_km = 300000
tiempo_segundos = 3600

# Cálculo de precisión
print(f"División real: {distancia_luz_km / tiempo_segundos}")
print(f"División entera (truncada): {distancia_luz_km // tiempo_segundos}")
print(f"Resto de la operación (módulo): {distancia_luz_km % tiempo_segundos}")

# El curioso caso de los decimales
print(f"\n¿Cuánto es 0.1 + 0.2 en Python? {0.1 + 0.2}")

# %% [markdown]
# ## 2. Bloque de Debugging 🛠️
# Un ingeniero junior intentó calcular la energía cinética ($E_c = \frac{1}{2}mv^2$) de un dron, pero el código falla.
# **Misión:** Encuentra los 3 errores y haz que funcione.

# %%
# --- CÓDIGO CON ERRORES ---

masa = 2.5
velocidad = 1
energia = 1/2 * masa * velocidad**2

print("La energía cinética es: " + str(energia) + " J")
